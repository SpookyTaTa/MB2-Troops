# %%
import pandas as pd

# %%
mb2 = pd.read_excel(r"C:\Users\Tom\Documents\MB2.xlsx")
# pd.set_option("display.max_columns", 4)

# %%
mb2.sort_values("2Hand", ascending=False).head(10)
# Out:
#       Culture      Faction                   Name  Tier TroopType  TreeType  \
# 39   Battania     Battania          Fian Champion     6    Ranged     Noble
# 187   Sturgia  Sea Raiders        Sea Raider Boss     5  Infantry    Bandit
# 91    Sturgia      Sturgia    Heroic Line Breaker     5  Infantry  Commoner
# 14     Aserai       Aserai  Mameluke Palace Guard     5  Infantry  Commoner
# 38   Battania     Battania                   Fian     5    Ranged     Noble
# 111   Vlandia      Vlandia                Pikeman     5  Infantry  Commoner
# 110   Vlandia      Vlandia               Voulgier     5  Infantry  Commoner
# 37   Battania     Battania                   Hero     4    Ranged     Noble
# 86    Sturgia      Sturgia               Beserker     4  Infantry  Commoner
# 106   Vlandia      Vlandia                Billman     4  Infantry  Commoner
#
#     1Hand  2Hand  Polearm  Bow  Crossbow  Throwing  Riding  Athletics
# ...
